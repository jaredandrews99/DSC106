# %%
import pandas as pd

# %%
df = pd.read_csv('ucsd_cds_admission_data_2005_to_2018.csv')

# %%
for i in df.columns[1:]:
    df[i] = df[i].apply(lambda x: int(x.replace(',','')))

# %%
df.set_index('year',inplace=True)

# %%
df.to_csv('/Users/jaredandrews/Applications/DSC106/DSC106HW1/ucsd_admission_lp.csv')

# %%
type(df['fulltime_men_applied'][0])
# Out:
# str

# %%
df
# Out:
#     year  fulltime_men_applied  fulltime_women_applied  fulltime_men_admitted  \
# 0   2018                 45636                   52265                  13781
# 1   2017                 41583                   46845                  13981
# 2   2016                 39779                   44430                  14103
# 3   2015                 37009                   41047                  12748
# 4   2014                 34618                   38822                  11758
# 5   2013                 31992                   35408                  11866
# 6   2012                 28758                   32049                  10917
# 7   2011                 25097                   28351                   8707
# 8   2010                 22332                   25761                   8365
# 9   2009                 21725                   25321                   7816
# 10  2008                 21590                   25775                   8517
# ...
